# %% [markdown]
# # Assignment 1
#
# ## Question 1 - Bangkok
# ![Bangkok](https://upload.wikimedia.org/wikipedia/commons/f/f6/Bangkok_skytrain_sunset.jpg)
# (Image courtesy of [Wikimedia Commons](https://en.wikipedia.org/wiki/Bangkok#/media/File:Bangkok_skytrain_sunset.jpg))
#
# For this question I chose **Bangkok** as my *favorite* city because I was born there. It is the capital of **Thailand** as well asthe most populous city. There are over 8 million people living in the capital, which accounts for 12.6 percent of the country's population. At the same time, an aditional 14 million live in the surrounding [Bangkok Metropolitan Area](https://en.wikipedia.org/wiki/Bangkok_Metropolitan_Region) along the *Chao Phraya* River which runs through the city up north and into the gulf of Thailand. Along with the local population, tourists love coming to Bangkok to experience Thai culture as well as for business endeavors as Bangkok is a major regional international hub for finance, business, air transportation as well as for fashion and the arts. Here are soeme link to introduce you to the various places, attractions, events, people which makes the city unique
# * [**Wat Arun Temple**](https://en.wikipedia.org/wiki/Wat_Arun) -- One of the most famous temple by the *Chao Phraya* River
# * [**Local Events**](http://www.bangkokpost.com/lifestyle/) -- The Bangkok Post is considered by some as the ***best*** english new source for current events in Thailand as well as Bangkok. This link will take you to the lifestyle section.
# * [**The Monarch**](https://en.wikipedia.org/wiki/Vajiralongkorn) -- Thailand is a constitutional monarchy and as such the King is our head of state. In order to have a better understanding of **Thailand** knowing about him may be a good idea
# * [**NY Times Travel Recomaendation**](https://www.nytimes.com/2016/05/01/travel/bangkok-thailand-river-of-kings.html) -- A spectacular article written by the New York times planning out for you an **amazing** adventure for the city.
#
# ## Question 2
#
# Here is a list of my favorite courses thus far from my two years of UBC
#
# * First Year
#     * [ECON 101 Principles of Microeconomics](https://courses.students.ubc.ca/cs/main?pname=subjarea&tname=subjareas&req=3&dept=ECON&course=101)
#     * [ECON 102 Principle of Macroeconomics](https://courses.students.ubc.ca/cs/main?pname=subjarea&tname=subjareas&req=3&dept=ECON&course=102)
#     * [MATH 100 Differential Calculus with Applications to Physical Sciences and Engineering](https://courses.students.ubc.ca/cs/main?pname=subjarea&tname=subjareas&req=3&dept=MATH&course=100)
#     * [MATH 101 Integral Calculus with Applications to Physical Sciences and Engineering](https://courses.students.ubc.ca/cs/main?pname=subjarea&tname=subjareas&req=3&dept=MATH&course=101)
# * Second Year
#     * [MATH 221 Matrix Algebra](https://courses.students.ubc.ca/cs/main?pname=subjarea&tname=subjareas&req=3&dept=MATH&course=221)
#     * [ECON 211 Macroeconomic Policy](https://courses.students.ubc.ca/cs/main?pname=subjarea&tname=subjareas&req=3&dept=ECON&course=211)
#     * [ECON 226 Making Sense of Economic Data](https://courses.students.ubc.ca/cs/main?pname=subjarea&tname=subjareas&req=3&dept=ECON&course=226)
#
# ## Question 3
#
# $$
# \begin{bmatrix} 5 & 2 & 1 \\ 3 & 7 & 1 \\ 2 & 0 & 4 \end{bmatrix}
# \ \begin{bmatrix} x_1 \\ x_2 \\ x_3 \end{bmatrix} \ =
# \ \begin{bmatrix} 0 \\ 1 \\ 3 \end{bmatrix}
# $$
#
# ## Question 4
#
# The Maxwell-Faraday equation:
#
# $$
# \oint_{\partial \Sigma} \mathbf{E} \cdot d\boldsymbol{\ell} = -\frac{d}{dt} \int \!\!\! \int_{\Sigma} \mathbf{B} \cdot d \mathbf{S}
# $$
#
# ## Question 5
#
# The Black-Scholes equation:
#
# $$
# \frac{\partial V}{\partial t} +
# \frac{1}{2}\sigma^2 S^2 \frac{\partial^2 V}{\partial S^2} +
# rS \frac{\partial V}{\partial S} -
# rV = 0
# $$
#
# ## Question 6
#
# After having looked over my PHYS 118 notes as a source for complex formulas to demonstrate LaText writing, the summation of all work done in a system of charges seems like an appropriate formula to describe.
#
# In LaTex:
#
# $$
# W = \sum_{j}(F_s)_j \Delta s_j \rightarrow \int_{s_i}^{s_f} F_s ds = \int_{i}^{f} \vec{F} \cdot d \vec{s}
# $$
#
#
# From the formula booklet we have:
# ![workdone](http://i.imgur.com/OzvpCTI.png)
